# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/Josh/codeup-data-science/numpy-pandas-visualization-exercises/mytable_customer_details - Copy of Table1_CustDetails.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7043 non-null   object
#  1   gender                  7043 non-null   object
#  2   is_female               7043 non-null   bool
#  3   is_senior_citizen       7043 non-null   int64
#  4   partner                 7043 non-null   object
#  5   dependents              7043 non-null   object
#  6   partner_dependents      7043 non-null   int64
#  7   phone_service           7043 non-null   int64
#  8   has_phone               7043 non-null   bool
#  9   internet_service        7043 non-null   int64
#  10  has_internet            7043 non-null   bool
#  11  has_phone_and_internet  7043 non-null   bool
#  12  contract_type           7043 non-null   int64
#  13  payment_type            7043 non-null   object
# ...

# %%
month_to_month = df[df['contract_type.1']=='Month-to-Month']

# %%
churned = df[df['churn']=='Yes']

# %%
churned
# Out:
#      customer_id  gender  is_female  is_senior_citizen partner dependents  \
# 2     0004-TLHLJ    Male      False                  0      No         No
# 3     0011-IGKFF    Male      False                  1     Yes         No
# 4     0013-EXCHZ  Female       True                  1     Yes         No
# 18    0022-TCJCI    Male      False                  1      No         No
# 19    0023-HGHWL    Male      False                  1      No         No
# ...          ...     ...        ...                ...     ...        ...
# 7017  9957-YODKZ    Male      False                  1      No         No
# 7025  9968-FFVVH  Female       True                  0     Yes        Yes
# 7036  9985-MWVIX  Female       True                  0      No         No
# 7037  9986-BONCE  Female       True                  0      No         No
# 7039  9992-RRAMN    Male      False                  0     Yes         No
#
#       partner_dependents  phone_service  has_phone  internet_service  ...  \
# ...

# %%
churned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1869 entries, 2 to 7039
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             1869 non-null   object
#  1   gender                  1869 non-null   object
#  2   is_female               1869 non-null   bool
#  3   is_senior_citizen       1869 non-null   int64
#  4   partner                 1869 non-null   object
#  5   dependents              1869 non-null   object
#  6   partner_dependents      1869 non-null   int64
#  7   phone_service           1869 non-null   int64
#  8   has_phone               1869 non-null   bool
#  9   internet_service        1869 non-null   int64
#  10  has_internet            1869 non-null   bool
#  11  has_phone_and_internet  1869 non-null   bool
#  12  contract_type           1869 non-null   int64
#  13  payment_type            1869 non-null   object
# ...

# %% [markdown]
# ### Percentage of all customers that have churned

# %%
len(churned)/len(df)
# Out:
# 0.2653698707936959

# %%
churned_month_to_month = churned[churned['contract_type.1'] == 'Month-to-Month']

# %%
churned_month_to_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1655 entries, 2 to 7039
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             1655 non-null   object
#  1   gender                  1655 non-null   object
#  2   is_female               1655 non-null   bool
#  3   is_senior_citizen       1655 non-null   int64
#  4   partner                 1655 non-null   object
#  5   dependents              1655 non-null   object
#  6   partner_dependents      1655 non-null   int64
#  7   phone_service           1655 non-null   int64
#  8   has_phone               1655 non-null   bool
#  9   internet_service        1655 non-null   int64
#  10  has_internet            1655 non-null   bool
#  11  has_phone_and_internet  1655 non-null   bool
#  12  contract_type           1655 non-null   int64
#  13  payment_type            1655 non-null   object
# ...

# %%
len(churned_month_to_month)/len(month_to_month)
# Out:
# 0.4272070211667527

# %%
churned_month_to_month['service_type'].value_counts()
# Out:
# phone_and_internet    1403
# internet_only          153
# phone_only              99
# Name: service_type, dtype: int64

# %%
df['service_type'].value_counts()
# Out:
# phone_and_internet    4835
# phone_only            1526
# internet_only          682
# Name: service_type, dtype: int64

# %% [markdown]
# ### Percentage of month to month users that have churned

# %%
churned_month_to_month.size/churned.size
# Out:
# 0.8855002675227395

# %%
churned_phone_and_internet = churned[churned['service_type']=='phone_and_internet']
churned_phone_and_internet
# Out:
#      customer_id  gender  is_female  is_senior_citizen partner dependents  \
# 2     0004-TLHLJ    Male      False                  0      No         No
# 3     0011-IGKFF    Male      False                  1     Yes         No
# 4     0013-EXCHZ  Female       True                  1     Yes         No
# 18    0022-TCJCI    Male      False                  1      No         No
# 21    0023-XUOPT  Female       True                  0     Yes         No
# ...          ...     ...        ...                ...     ...        ...
# 7007  9940-RHLFB    Male      False                  0     Yes         No
# 7014  9950-MTGYX    Male      False                  1      No         No
# 7017  9957-YODKZ    Male      False                  1      No         No
# 7036  9985-MWVIX  Female       True                  0      No         No
# 7039  9992-RRAMN    Male      False                  0     Yes         No
#
#       partner_dependents  phone_service  has_phone  internet_service  ...  \
# ...

# %%
churned_phone_and_internet.size/churned.size
# Out:
# 0.8485821294810059

# %%
churned_phone_and_internet.size/churned_month_to_month.size
# Out:
# 0.9583081570996979

# %%
churned_internet = churned[churned['service_type']=='internet_only']

# %%
churned_internet.size
# Out:
# 4250

# %%
churned_phone = churned[churned['service_type']=='phone_only']

# %%
churned_phone.size
# Out:
# 2825

# %%
churned['tenure'].value_counts()
# Out:
# 1     448
# 2      98
# 3      90
# 4      79
# 5      53
#      ...
# 71      4
# 72      4
# 62      2
# 73      2
# 74      1
# Name: tenure, Length: 74, dtype: int64

# %%
churned_one_month = churned[churned['tenure']==1]

# %%
churned_one_month['avg_monthly_charges']
# Out:
# 19      $25.10
# 34      $91.10
# 57      $19.85
# 58      $99.75
# 80      $80.20
#          ...
# 6965    $74.30
# 6974    $25.05
# 7001    $75.30
# 7025    $30.50
# 7036    $70.15
# Name: avg_monthly_charges, Length: 448, dtype: object

# %%
churned_one_month.size/churned.size
# Out:
# 0.2397003745318352

# %%
df[df['tenure']==1].size
# Out:
# 18600

# %%
not_churned = df[df['churn']=='No']

# %%
not_churned[not_churned['contract_type.1']=='Month-to-Month']
# Out:
#      customer_id  gender  is_female  is_senior_citizen partner dependents  \
# 1     0003-MKNFE    Male      False                  0      No         No
# 5     0013-MHZWF  Female       True                  0      No        Yes
# 8     0015-UOCOJ  Female       True                  1      No         No
# 12    0018-NYROU  Female       True                  0     Yes         No
# 17    0021-IKXGC  Female       True                  1      No         No
# ...          ...     ...        ...                ...     ...        ...
# 7021  9962-BFPDU    Male      False                  1     Yes        Yes
# 7023  9965-YOKZB  Female       True                  0      No         No
# 7031  9974-JFBHQ    Male      False                  0      No        Yes
# 7033  9975-SKRNR    Male      False                  0      No         No
# 7040  9992-UJOEL    Male      False                  0      No         No
#
#       partner_dependents  phone_service  has_phone  internet_service  ...  \
# ...

# %%
churned_month_to_month['service_type'].value_counts()
# Out:
# phone_and_internet    1403
# internet_only          153
# phone_only              99
# Name: service_type, dtype: int64

# %%
df_monthly = df[df['contract_type.1']=='Month-to-Month']
df_monthly
# Out:
#      customer_id  gender  is_female  is_senior_citizen partner dependents  \
# 1     0003-MKNFE    Male      False                  0      No         No
# 2     0004-TLHLJ    Male      False                  0      No         No
# 3     0011-IGKFF    Male      False                  1     Yes         No
# 4     0013-EXCHZ  Female       True                  1     Yes         No
# 5     0013-MHZWF  Female       True                  0      No        Yes
# ...          ...     ...        ...                ...     ...        ...
# 7033  9975-SKRNR    Male      False                  0      No         No
# 7036  9985-MWVIX  Female       True                  0      No         No
# 7037  9986-BONCE  Female       True                  0      No         No
# 7039  9992-RRAMN    Male      False                  0     Yes         No
# 7040  9992-UJOEL    Male      False                  0      No         No
#
#       partner_dependents  phone_service  has_phone  internet_service  ...  \
# ...

# %%
df_monthly['service_type'].value_counts()
# Out:
# phone_and_internet    2974
# phone_only             524
# internet_only          376
# Name: service_type, dtype: int64

# %%
df_monthly['tenure'].value_counts()
# Out:
# 1     729
# 2     202
# 3     176
# 4     154
# 9     106
#      ...
# 65      9
# 67      9
# 64      9
# 69      3
# 70      2
# Name: tenure, Length: 71, dtype: int64

# %%
churned_month_to_month['tenure'].value_counts()
# Out:
# 1     446
# 2      98
# 3      90
# 4      77
# 5      53
#      ...
# 55      1
# 61      1
# 62      1
# 69      1
# 70      1
# Name: tenure, Length: 70, dtype: int64

# %%
churned_mtm = pd.DataFrame(churned_month_to_month['tenure'].value_counts())
churned_mtm
# Out:
#     tenure
# 1      446
# 2       98
# 3       90
# 4       77
# 5       53
# ..     ...
# 55       1
# 61       1
# 62       1
# 69       1
# 70       1
#
# [70 rows x 1 columns]

# %%
df_one_year = df[df['contract_type.1']=='1 Year']
df_one_year['tenure'].mean()
# Out:
# 41.510522742701966

# %%
df_two_years = df[df['contract_type.1']=='2 Year']
df_two_years['tenure'].mean()
# Out:
# 56.30129716981132

# %%
churned_fiber = churned[churned['internet_service.1']=='Fiber Optic']
churned_fiber[churned_fiber['phone_service.1']=='Two or More Lines']
# Out:
#      customer_id  gender  is_female  is_senior_citizen partner dependents  \
# 21    0023-XUOPT  Female       True                  0     Yes         No
# 47    0080-OROZO    Male      False                  0      No         No
# 58    0100-DUVFC    Male      False                  0      No        Yes
# 65    0111-KLBQG    Male      False                  0     Yes         No
# 69    0114-PEGZZ  Female       True                  0      No         No
# ...          ...     ...        ...                ...     ...        ...
# 6977  9903-LYSAB  Female       True                  1     Yes         No
# 6986  9917-KWRBE  Female       True                  0      No         No
# 7000  9932-WBWIK  Female       True                  0     Yes         No
# 7017  9957-YODKZ    Male      False                  1      No         No
# 7039  9992-RRAMN    Male      False                  0     Yes         No
#
#       partner_dependents  phone_service  has_phone  internet_service  ...  \
# ...

# %%
churned_fiber['dependents'].value_counts()
# Out:
# No     1095
# Yes     202
# Name: dependents, dtype: int64

# %%
churned_fiber['partner'].value_counts()
# Out:
# No     795
# Yes    502
# Name: partner, dtype: int64
